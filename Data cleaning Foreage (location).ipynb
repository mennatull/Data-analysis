# %%
import os
import pandas as pd

# %%
os.chdir("/Users/mennatullahalsoudi/Downloads")

# %%
os.getcwd
# Out:
# <function posix.getcwd()>

# %%
df=pd.read_csv("Location (1).csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                               User ID  \
# 0           0             0  4c731e48-0377-4d7d-b4c8-b2174b774ed8
# 1           1             1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 2           2             2  a8229d24-f219-4930-a382-24049a8f73bb
# 3           3             3  8f41c07f-db4f-44f3-ae81-1f99cee047eb
# 4           4             4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
#
#                                              Address
# 0        6208 Wright Mountains\nBryantfurt, AR 02531
# 1  534 Williams Turnpike Suite 788\nPort Julie, W...
# 2  867 Lisa Causeway Apt. 015\nWest Brentmouth, A...
# 3  5687 Wilson Harbors Suite 763\nLake Robert, FL...
# 4                    2614Unit Box 8996\nDPO,AE 23660

# %%
df.isna()
# Out:
#      Unnamed: 0  Unnamed: 0.1  User ID  Address
# 0         False         False    False    False
# 1         False         False    False    False
# 2         False         False    False    False
# 3         False         False    False    False
# 4         False         False    False    False
# ..          ...           ...      ...      ...
# 495       False         False    False    False
# 496       False         False    False    False
# 497       False         False    False    False
# 498       False         False    False    False
# 499       False         False    False    False
#
# [500 rows x 4 columns]

# %%
df.dropna()
# Out:
#      Unnamed: 0  Unnamed: 0.1                               User ID  \
# 0             0             0  4c731e48-0377-4d7d-b4c8-b2174b774ed8
# 1             1             1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 2             2             2  a8229d24-f219-4930-a382-24049a8f73bb
# 3             3             3  8f41c07f-db4f-44f3-ae81-1f99cee047eb
# 4             4             4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
# ..          ...           ...                                   ...
# 495         495           495  1f7e22c8-558a-4b6f-a04f-b219593f029e
# 496         496           496  0d47a133-383b-4a9c-976c-697ac65ccb19
# 497         497           497  db0066e1-83cc-43f3-990b-983010aa5370
# 498         498           498  d6204684-926d-41db-ae9c-a7bf2e76313a
# 499         499           499  07f4dcd0-2bf3-4f21-9da3-b054b511ae00
#
#                                                Address
# 0          6208 Wright Mountains\nBryantfurt, AR 02531
# ...

# %%
df.isna().sum()
#Make sure there is no nan values in the dataframe
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# User ID         0
# Address         0
# dtype: int64

# %%
df["User ID"].unique()
# Out:
# array(['4c731e48-0377-4d7d-b4c8-b2174b774ed8',
#        '95258c36-5b6b-4591-85ee-0c43f503c1d5',
#        'a8229d24-f219-4930-a382-24049a8f73bb',
#        '8f41c07f-db4f-44f3-ae81-1f99cee047eb',
#        '3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9',
#        '2bd9c167-e06c-47c1-a978-3403d6724606',
#        '7dd7dec0-5758-4a6e-a7dd-27a20e57c757',
#        'f62c96d8-5b1e-45c6-8a65-b36a9387827d',
#        '22056f9e-4654-44e9-930d-2fabdeb80f95',
#        '30a7de62-d6a1-47d6-963f-0724adf18c4b',
#        'c7b6e374-1bef-48c3-8222-cc231dbd5cce',
#        'eff1e86a-8ede-4a41-818b-9442e3181ee3',
#        '346174b1-4661-4cdd-8c47-66dbd013cd56',
#        '0f1f6aef-b094-4b4d-b6b6-412ebc42c12b',
#        '0828c4e1-63ec-4121-aa07-eefd37954bb9',
#        '8665a934-dc22-482b-9289-2e2c9d6a4095',
#        'd4dc38d4-5c80-428f-95da-b746a275531c',
#        '5ff89fb3-b364-494f-b62d-07097b2ffa12',
#        'bbef3be1-172e-44bb-be3b-013140707ecf',
#        'fb4654ff-ce23-4a77-b52a-50f8948b5664',
# ...

# %%
df["Address"].unique()
# Out:
# array(['6208 Wright Mountains\nBryantfurt, AR 02531',
#        '534 Williams Turnpike Suite 788\nPort Julie, WA 70786',
#        '867 Lisa Causeway Apt. 015\nWest Brentmouth, AL 99540',
#        '5687 Wilson Harbors Suite 763\nLake Robert, FL 22223',
#        '2614Unit Box 8996\nDPO,AE 23660',
#        '42350 Wilson Turnpike Suite 472\nMendezmouth, VT 50550',
#        '998 Lauren Villages Suite 720\nSusanland, HI 92070',
#        '418 Jennifer Motorway Suite 815\nCruzview, GA 03543',
#        '271 Ashley Fork Suite 100\nMichaelburgh, MO 35011',
#        '56824 Crystal Freeway\nHoovermouth, ME 38682',
#        '4719 Joseph Cape Apt. 672\nPort Nathanielhaven, SC 42585',
#        '8330 PSC, Box 1422\nAPO, AP 16415',
#        '24228 Abbott Roads\nJohnsonhaven, AZ 90289',
#        '8639 Gary Springs\nRonaldview, HI 08179',
#        '8690 Martin Hollow\nJanetfurt, MN 29250',
#        '23776 Nathan Street\nNew Andrew, ME 65273',
#        '9080 PSC, Box 4772\nAPO ,AE 11277',
# ...

# %%
bool_serious=df.duplicated()
print(bool_serious)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
#MAKING ALL THE ADDRESS IN THE SAME FORMAT AS FORM OF DATA CLEANING ..........

# %%
df["Address"].replace("Unit 2614 Box 8996\nDPO AE 23660","2614Unit Box 8996\nDPO,AE 23660",inplace=True)

# %%
df["Address"].replace("PSC 8330, Box 1422\nAPO AP 16415","8330 PSC, Box 1422\nAPO, AP 16415",inplace=True)

# %%
df["Address"].replace("PSC 9080, Box 4772\nAPO AE 11277","9080 PSC, Box 4772\nAPO ,AE 11277",inplace=True)

# %%
df["Address"].replace("USNV Brown\nFPO AE 46644","USNV Brown\nFPO, AE 46644",inplace=True)

# %%
df["Address"].replace("USS Hahn\nFPO AA 69593","USS Hahn\nFPO, AA 69593",inplace=True)

# %%
df["Address"].replace("PSC 9038, Box 4090\nAPO AP 52456","9038 PSC , Box 4090\nAPO ,AP 52456",inplace=True)

# %%
df["Address"].replace("PSC 8622, Box 3896\nAPO AP 71913","8622 PSC, Box 3896\nAPO ,AP 71913",inplace=True)

# %%
df["Address"].replace("PSC 2768, Box 0408\nAPO AA 38458","8003 Unit Box 5162\nDPO ,AP 61225",inplace=True)

# %%
df["Address"].replace("Unit 8003 Box 5162\nDPO AP 61225","8003 Unit Box 5162\nDPO ,AP 61225",inplace=True)

# %%
df["Address"].replace("Unit 0551 Box 4181\nDPO AA 15539","0551 Unit Box 4181\nDPO ,AA 15539",inplace=True)

# %%
df["Address"].replace("Unit 4373 Box 3248\nDPO AA 01188","4373 Unit Box 3248\nDPO ,AA 01188",inplace=True)

# %%
df["Address"].replace("PSC 3816, Box 4398\nAPO AA 82519","3816 PSC, Box 4398\nAPO ,AA 82519",inplace=True)

# %%
df["Address"].replace("USCGC Cunningham\nFPO AE 04893","USCGC Cunningham\nFPO ,AE 04893",inplace=True)

# %%
df["Address"].replace("PSC 9104, Box 9179\nAPO AP 34539","9104 PSC, Box 9179\nAPO ,AP 34539",inplace=True)

# %%
df["Address"].replace("Unit 8764 Box 5726\nDPO AE 56727","8764 Unit Box 5726\nDPO ,AE 56727",inplace=True)

# %%
df["Address"].replace("PSC 0909, Box 1784\nAPO AA 16657","0909 PSC, Box 1784\nAPO ,AA 16657",inplace=True)

# %%
df["Address"].replace("Unit 8694 Box 8359\nDPO AP 98988","8694 Unit Box 8359\nDPO ,AP 98988",inplace=True)

# %%
df["Address"].replace("PSC 0757, Box 2246\nAPO AP 59935","0757 PSC, Box 2246\nAPO ,AP 59935",inplace=True)

# %%
df["Address"].replace("Unit 8199 Box 1582\nDPO AP 88280","8199 Unit Box 1582\nDPO AP 88280",inplace=True)

# %%
df["Address"].replace("USNS Bird\nFPO AE 07625","USNS Bird\nFPO ,AE 07625",inplace=True)

# %%
df["Address"].replace("PSC 7263, Box 9049\nAPO AA 08308","7263 PSC, Box 9049\nAPO ,AA 08308",inplace=True)

# %%
df["Address"].replace("USCGC Simpson\nFPO AP 24488","USCGC Simpson\nFPO ,AP 24488",inplace=True)

# %%
df["Address"].replace("Unit 2127 Box 7084\nDPO AP 47768","2127 Unit Box 7084\nDPO ,AP 47768",inplace=True)

# %%
df["Address"].replace("Unit 7779 Box 7818\nDPO AE 22183","7779 Unit Box 7818\nDPO ,AE 22183",inplace=True)

# %%
df["Address"].replace("PSC 1888, Box 5510\nAPO AA 90778","1888 PSC, Box 5510\nAPO ,AA 90778",inplace=True)

# %%
df["Address"].replace("USNS Schneider\nFPO AE 13152","USNS Schneider\nFPO ,AE 13152",inplace=True)

# %%
df["Address"].replace("Unit 4550 Box 8148\nDPO AP 47371","4550 Unit Box 8148\nDPO ,AP 47371",inplace=True)

# %%
df["Address"].replace("Unit 8902 Box 9429\nDPO AP 73681","8902 Unit  Box 9429\nDPO ,AP 73681",inplace=True)

# %%
df["Address"].replace("PSC 4430, Box 8569\nAPO AP 15240","4430 PSC, Box 8569\nAPO ,AP 15240",inplace=True)

# %%
df["Address"].replace("Unit 0892 Box 7484\nDPO AE 41789","0892 Unit Box 7484\nDPO ,AE 41789",inplace=True)

# %%
df["Address"].replace("Unit 1015 Box 5864\nDPO AA 10815","1015 Unit Box 5864\nDPO ,AA 10815",inplace=True)

# %%
df["Address"].replace("Unit 7564 Box 1230\nDPO AP 95924","7564 Unit Box 1230\nDPO ,AP 95924",inplace=True)

# %%
df["Address"].replace("USS Thomas\nFPO AA 04495","USS Thomas\nFPO ,AA 04495",inplace=True)

# %%
df["Address"].replace("Unit 3999 Box 7280\nDPO AP 36681","3999 Unit Box 7280\nDPO ,AP 36681",inplace=True)

# %%
df["Address"].replace("Unit 3930 Box 4373\nDPO AP 90809","3930 Unit Box 4373\nDPO ,AP 90809",inplace=True)

# %%
df["Address"].replace("Unit 8924 Box 8191\nDPO AP 75694","8924 Unit Box 8191\nDPO ,AP 75694",inplace=True)

# %%
df["Address"].replace("PSC 7480, Box 4771\nAPO AE 82831","7480 PSC, Box 4771\nAPO ,AE 82831",inplace=True)

# %%
df["Address"].replace("Unit 6479 Box 6124\nDPO AE 50619","6479 Unit Box 6124\nDPO AE 50619",inplace=True)

# %%
df["Address"].replace("USNV Newman\nFPO AE 24533","USNV Newman\nFPO ,AE 24533",inplace=True)

# %%
df["Address"].replace("USS Henry\nFPO AE 30895","USS Henry\nFPO ,AE 30895",inplace=True)

# %%
df["Address"].replace("PSC 8837, Box 6590\nAPO AE 71776","8837 PSC, Box 6590\nAPO ,AE 71776",inplace=True)

# %%
df["Address"].replace("USNV Wright\nFPO AA 24117","USNV Wright\nFPO ,AA 24117",inplace=True)

# %%
df["Address"].replace("Unit 2884 Box 7963\nDPO AE 42637","2884 Unit  Box 7963\nDPO ,AE 42637",inplace=True)

# %%
df["Address"].replace("USNV Lee\nFPO AP 28828","USNV Lee\nFPO ,AP 28828",inplace=True)

# %%
df["Address"].replace("USS Dawson\nFPO AA 46857","USS Dawson\nFPO ,AA 46857",inplace=True)

# %%
df["Unnamed: 0"].mean()
# Out:
# 249.5

# %%
df.head(50)
# Out:
#     Unnamed: 0  Unnamed: 0.1                               User ID  \
# 0            0             0  4c731e48-0377-4d7d-b4c8-b2174b774ed8
# 1            1             1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 2            2             2  a8229d24-f219-4930-a382-24049a8f73bb
# 3            3             3  8f41c07f-db4f-44f3-ae81-1f99cee047eb
# 4            4             4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
# 5            5             5  2bd9c167-e06c-47c1-a978-3403d6724606
# 6            6             6  7dd7dec0-5758-4a6e-a7dd-27a20e57c757
# 7            7             7  f62c96d8-5b1e-45c6-8a65-b36a9387827d
# 8            8             8  22056f9e-4654-44e9-930d-2fabdeb80f95
# 9            9             9  30a7de62-d6a1-47d6-963f-0724adf18c4b
# 10          10            10  c7b6e374-1bef-48c3-8222-cc231dbd5cce
# 11          11            11  eff1e86a-8ede-4a41-818b-9442e3181ee3
# 12          12            12  346174b1-4661-4cdd-8c47-66dbd013cd56
# ...

# %%
df.to_csv("Location clean(1).csv")
