# %%
import os
import pandas as pd
import numpy as np

# %%
os.chdir("/Users/mennatullahalsoudi/Downloads")

# %%
os.getcwd
# Out:
# <function posix.getcwd()>

# %%
df=pd.read_csv("Reactions (1).csv")

# %%
df.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01

# %%
df.isna()
df.isna().sum()
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# ...

# %%
df["User ID"].replace('', np.nan)
# Out:
# 0                                         NaN
# 1        5d454588-283d-459d-915d-c48a2cb4c27f
# 2        92b87fa5-f271-43e0-af66-84fac21052e6
# 3        163daa38-8b77-48c9-9af6-37a6c1447ac2
# 4        34e8add9-0206-47fd-a501-037b994650a2
#                          ...
# 25548    80c9ce48-46f9-4f5e-b3ca-3b698fc2e949
# 25549    2bd9c167-e06c-47c1-a978-3403d6724606
# 25550                                     NaN
# 25551    5ffd8b51-164e-47e2-885e-8b8c46eb63ed
# 25552    4edc3d1a-a7d9-4db6-89c3-f784d9954172
# Name: User ID, Length: 25553, dtype: object

# %%
#Dropping all the none values in the type to keep the data clean
df.dropna(axis="index",how="any",subset=["Type"],inplace=True)

# %%
#Dropping the the none values in the userID t avoid any problems in the ML phase
df.dropna(axis="index",how="any",subset=["User ID"],inplace=True)

# %%
df
# Out:
#        Unnamed: 0                            Content ID  \
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25547       25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# ...

# %%
#Making sure data is clean 
df.isna().sum()
# Out:
# Unnamed: 0    0
# Content ID    0
# User ID       0
# Type          0
# Datetime      0
# dtype: int64

# %%
#Making sure that the all the data is numerical 
df["Unnamed: 0"].sum()
# Out:
# 287985721

# %%
#Sorting the data by the DATE AND TIME to be more clear in the data visualization 
df["Datetime"] = pd.to_datetime(df["Datetime"])

df = df.sort_values(by="Datetime")

# %%
df
# Out:
#        Unnamed: 0                            Content ID  \
# 15124       15124  a727ed7f-5684-4536-b543-8e8fc93f40b1
# 23886       23886  edea43f3-1541-4e42-8419-d1cdf749025c
# 23566       23566  a8160135-2d55-4240-8f28-fbee5ec84801
# 4222         4222  6e418568-a2b9-4d08-b241-06362c96a7f1
# 19420       19420  8f4cea30-10e7-4806-8c01-d78ef6bcbfa8
# ...           ...                                   ...
# 20216       20216  c3d1c36d-2ad9-45ce-be49-51c103351e62
# 6903         6903  70b0202f-cd58-42fe-acd9-7b2f8cf9e7c6
# 17192       17192  18cb1ce7-fb66-4a56-8042-e38c9593ade1
# 24592       24592  16f8b629-5173-420f-9c8b-577313e9e128
# 8721         8721  178f85a7-c2d1-4127-94d2-30adf96ae7fd
#
#                                     User ID       Type            Datetime
# 15124  b9480379-4b96-412c-8dca-96fff9ae81a3       hate 2020-06-18 08:07:22
# 23886  92423e9a-4e8c-49bc-be75-c819912696ce  intrigued 2020-06-18 08:51:33
# ...

# %%
df.to_csv("Reactions (1).csv")
