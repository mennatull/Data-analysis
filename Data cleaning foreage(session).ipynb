# %%
import os
import pandas as pd
import numpy as np

# %%
os.chdir("/Users/mennatullahalsoudi/Downloads")

# %%
os.getcwd
# Out:
# <function posix.getcwd()>

# %%
df=pd.read_csv("Session (1)(1).csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                               User ID     Device  \
# 0           0             0  4c731e48-0377-4d7d-b4c8-b2174b774ed8  Microsoft
# 1           1             1  95258c36-5b6b-4591-85ee-0c43f503c1d5      Apple
# 2           2             2  a8229d24-f219-4930-a382-24049a8f73bb        HTC
# 3           3             3  8f41c07f-db4f-44f3-ae81-1f99cee047eb   Motorola
# 4           4             4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9     Huawei
#
#    Duration
# 0        11
# 1        51
# 2        25
# 3        68
# 4        57

# %%
for i in range(len(df)):
    df["Device"].replace("Google",np.nan,inplace=True)

# %%
df.iloc[50:100,:]
# Out:
#     Unnamed: 0  Unnamed: 0.1                               User ID     Device  \
# 50          57            57  4cff698b-def1-497c-a78e-75058de67fe8     Huawei
# 51          58            58  5ffd8b51-164e-47e2-885e-8b8c46eb63ed     Huawei
# 52          59            59  95023c1b-04b7-4efd-ab34-61a4a70bb9d8        HTC
# 53          61            61  ad9f5c2f-aa30-4baf-b084-56b1a4b63b09  Microsoft
# 54          62            62  7bf3ce80-784e-42a0-b06a-dbbd1e31a9b7        HTC
# 55          63            63  92b87fa5-f271-43e0-af66-84fac21052e6     Huawei
# 56          64            64  ed1c744d-8561-4b41-b83c-7bf554fbca97      Apple
# 57          65            65  e8c9386c-8fbc-40cc-9587-ccb912ec5c10     Huawei
# 58          66            66  df1e7940-d514-40aa-af3a-e742792c4b5e    Samsung
# 59          67            67  6e9c7f30-264a-4aa0-b3ac-36e852d10906  Microsoft
# 60          68            68  69fcad9e-45a9-4189-b7e1-96b26c57c542     Huawei
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# User ID         0
# Device          0
# Duration        0
# dtype: int64

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1                               User ID  \
# 0             0             0  4c731e48-0377-4d7d-b4c8-b2174b774ed8
# 1             1             1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 2             2             2  a8229d24-f219-4930-a382-24049a8f73bb
# 3             3             3  8f41c07f-db4f-44f3-ae81-1f99cee047eb
# 4             4             4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
# ..          ...           ...                                   ...
# 428         495           495  1f7e22c8-558a-4b6f-a04f-b219593f029e
# 429         496           496  0d47a133-383b-4a9c-976c-697ac65ccb19
# 430         497           497  db0066e1-83cc-43f3-990b-983010aa5370
# 431         498           498  d6204684-926d-41db-ae9c-a7bf2e76313a
# 432         499           499  07f4dcd0-2bf3-4f21-9da3-b054b511ae00
#
#         Device  Duration
# 0    Microsoft        11
# 1        Apple        51
# 2          HTC        25
# 3     Motorola        68
# ...

# %%
df.dropna()
# Out:
#      Unnamed: 0  Unnamed: 0.1                               User ID  \
# 0             0             0  4c731e48-0377-4d7d-b4c8-b2174b774ed8
# 1             1             1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 2             2             2  a8229d24-f219-4930-a382-24049a8f73bb
# 3             3             3  8f41c07f-db4f-44f3-ae81-1f99cee047eb
# 4             4             4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
# ..          ...           ...                                   ...
# 428         495           495  1f7e22c8-558a-4b6f-a04f-b219593f029e
# 429         496           496  0d47a133-383b-4a9c-976c-697ac65ccb19
# 430         497           497  db0066e1-83cc-43f3-990b-983010aa5370
# 431         498           498  d6204684-926d-41db-ae9c-a7bf2e76313a
# 432         499           499  07f4dcd0-2bf3-4f21-9da3-b054b511ae00
#
#         Device  Duration
# 0    Microsoft        11
# 1        Apple        51
# 2          HTC        25
# 3     Motorola        68
# ...

# %%
#Replacing all the wrong values

# %%
df["Device"].replace("sbnnz",np.nan,inplace=True)

# %%
df["Device"].replace("thbhn",np.nan,inplace=True)

# %%
df["Device"].replace("ouafw",np.nan,inplace=True)

# %%
df["Device"].replace("xtzqw",np.nan,inplace=True)

# %%
df["Device"].replace("qxugb",np.nan,inplace=True)

# %%
df["Device"].replace("dcppv",np.nan,inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# User ID         0
# Device          0
# Duration        0
# dtype: int64

# %%
#Dropping all the null values

# %%
df.dropna(axis="index",how="any",subset=["Device"],inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# User ID         0
# Device          0
# Duration        0
# dtype: int64

# %%
df.to_csv("Session clean (1)(1).csv",index=False)
