# %%
import os
import pandas as pd

# %%
os.chdir("/Users/mennatullahalsoudi/Downloads")

# %%
os.getcwd
# Out:
# <function posix.getcwd()>

# %%
df=pd.read_csv("Profile (1).csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1                               User ID  \
# 0           1             1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 1           2             2  a8229d24-f219-4930-a382-24049a8f73bb
# 2           4             4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
# 3           5             5  2bd9c167-e06c-47c1-a978-3403d6724606
# 4           8             8  22056f9e-4654-44e9-930d-2fabdeb80f95
# 5           9             9  30a7de62-d6a1-47d6-963f-0724adf18c4b
# 6          10            10  c7b6e374-1bef-48c3-8222-cc231dbd5cce
# 7          11            11  eff1e86a-8ede-4a41-818b-9442e3181ee3
# 8          12            12  346174b1-4661-4cdd-8c47-66dbd013cd56
# 9          13            13  0f1f6aef-b094-4b4d-b6b6-412ebc42c12b
#
#                                            Interests  Age
# 0                                         ['tennis']   23
# 1        ['fitness', 'cooking', 'animals', 'travel']   25
# 2                                      ['education']   44
# ...

# %%
df.isna()
# Out:
#      Unnamed: 0  Unnamed: 0.1  User ID  Interests    Age
# 0         False         False    False      False  False
# 1         False         False    False      False  False
# 2         False         False    False      False  False
# 3         False         False    False      False  False
# 4         False         False    False      False  False
# ..          ...           ...      ...        ...    ...
# 420       False         False    False      False  False
# 421       False         False    False      False  False
# 422       False         False    False      False  False
# 423       False         False    False      False  False
# 424       False         False    False      False  False
#
# [425 rows x 5 columns]

# %%
#Making sure there is no none values
df.dropna()
# Out:
#      Unnamed: 0  Unnamed: 0.1                               User ID  \
# 0             1             1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 1             2             2  a8229d24-f219-4930-a382-24049a8f73bb
# 2             4             4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
# 3             5             5  2bd9c167-e06c-47c1-a978-3403d6724606
# 4             8             8  22056f9e-4654-44e9-930d-2fabdeb80f95
# ..          ...           ...                                   ...
# 420         494           494  7246fed1-8725-4dbb-bccd-5451346f122d
# 421         495           495  1f7e22c8-558a-4b6f-a04f-b219593f029e
# 422         497           497  db0066e1-83cc-43f3-990b-983010aa5370
# 423         498           498  d6204684-926d-41db-ae9c-a7bf2e76313a
# 424         499           499  07f4dcd0-2bf3-4f21-9da3-b054b511ae00
#
#                                              Interests  Age
# 0                                           ['tennis']   23
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# User ID         0
# Interests       0
# Age             0
# dtype: int64

# %%
#Making sure all the values are numerical
df["Age"].mean()
# Out:
# 25.305882352941175

# %%
df["Age"].unique()
# Out:
# array([23, 25, 44, 28, 30,  8, 32, 34, 42, 19, 21, 14, 41, 29, 39, 38,  7,
#         9, 16, 40, 35, 36, 26, 33, 20, 11, 18, 10, 15, 17,  6, 43, 22, 27,
#        24, 31, 37, 13, 12])

# %%
df.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1                               User ID  \
# 0           1             1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 1           2             2  a8229d24-f219-4930-a382-24049a8f73bb
# 2           4             4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
# 3           5             5  2bd9c167-e06c-47c1-a978-3403d6724606
# 4           8             8  22056f9e-4654-44e9-930d-2fabdeb80f95
# 5           9             9  30a7de62-d6a1-47d6-963f-0724adf18c4b
# 6          10            10  c7b6e374-1bef-48c3-8222-cc231dbd5cce
# 7          11            11  eff1e86a-8ede-4a41-818b-9442e3181ee3
# 8          12            12  346174b1-4661-4cdd-8c47-66dbd013cd56
# 9          13            13  0f1f6aef-b094-4b4d-b6b6-412ebc42c12b
#
#                                            Interests  Age
# 0                                         ['tennis']   23
# 1        ['fitness', 'cooking', 'animals', 'travel']   25
# 2                                      ['education']   44
# ...

# %%
df.drop("Age",axis=1)
# Out:
#      Unnamed: 0  Unnamed: 0.1                               User ID  \
# 0             1             1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 1             2             2  a8229d24-f219-4930-a382-24049a8f73bb
# 2             4             4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
# 3             5             5  2bd9c167-e06c-47c1-a978-3403d6724606
# 4             8             8  22056f9e-4654-44e9-930d-2fabdeb80f95
# ..          ...           ...                                   ...
# 420         494           494  7246fed1-8725-4dbb-bccd-5451346f122d
# 421         495           495  1f7e22c8-558a-4b6f-a04f-b219593f029e
# 422         497           497  db0066e1-83cc-43f3-990b-983010aa5370
# 423         498           498  d6204684-926d-41db-ae9c-a7bf2e76313a
# 424         499           499  07f4dcd0-2bf3-4f21-9da3-b054b511ae00
#
#                                              Interests
# 0                                           ['tennis']
# ...

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1                               User ID  \
# 0             1             1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 1             2             2  a8229d24-f219-4930-a382-24049a8f73bb
# 2             4             4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
# 3             5             5  2bd9c167-e06c-47c1-a978-3403d6724606
# 4             8             8  22056f9e-4654-44e9-930d-2fabdeb80f95
# ..          ...           ...                                   ...
# 420         494           494  7246fed1-8725-4dbb-bccd-5451346f122d
# 421         495           495  1f7e22c8-558a-4b6f-a04f-b219593f029e
# 422         497           497  db0066e1-83cc-43f3-990b-983010aa5370
# 423         498           498  d6204684-926d-41db-ae9c-a7bf2e76313a
# 424         499           499  07f4dcd0-2bf3-4f21-9da3-b054b511ae00
#
#                                              Interests  Age
# 0                                           ['tennis']   23
# ...

# %%
#Getting rid of all the unlogical values
for i in range(len(df)):
    if df["Age"][i]<=5:
        df.drop([i],axis=0,inplace=True)

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# Unnamed: 0.1     int64
# User ID         object
# Interests       object
# Age              int64
# dtype: object

# %%
#Cleaning the intrest columns 
df.iloc[0:50,:]
# Out:
#     Unnamed: 0  Unnamed: 0.1                               User ID  \
# 0            1             1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 1            2             2  a8229d24-f219-4930-a382-24049a8f73bb
# 2            4             4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
# 3            5             5  2bd9c167-e06c-47c1-a978-3403d6724606
# 4            8             8  22056f9e-4654-44e9-930d-2fabdeb80f95
# 5            9             9  30a7de62-d6a1-47d6-963f-0724adf18c4b
# 6           10            10  c7b6e374-1bef-48c3-8222-cc231dbd5cce
# 7           11            11  eff1e86a-8ede-4a41-818b-9442e3181ee3
# 8           12            12  346174b1-4661-4cdd-8c47-66dbd013cd56
# 9           13            13  0f1f6aef-b094-4b4d-b6b6-412ebc42c12b
# 10          15            15  8665a934-dc22-482b-9289-2e2c9d6a4095
# 11          16            16  d4dc38d4-5c80-428f-95da-b746a275531c
# ...

# %%
df.iloc[293:350,:]
# Out:
#      Unnamed: 0  Unnamed: 0.1                               User ID  \
# 293         348           348  bf721d00-4fa1-44b1-834f-4730cd51aefa
# 294         349           349  f0ef81ec-85b1-4475-ae60-aa7d373088aa
# 295         350           350  9b8a3e97-eee6-4de5-ab88-e00d2c0db6b9
# 296         351           351  61d88e0e-c0e7-4352-85ad-555e464ff933
# 297         352           352  2ad548cd-a899-4992-972b-92cde9cea8f1
# 298         353           353  ffdb3615-516c-422f-aa24-a137e3027d3a
# 299         354           354  31ff6616-c1dc-4b9a-8091-0b4d0cac25b1
# 300         356           356  941db1b1-270d-47f8-8a96-43f5a7481f03
# 301         357           357  e8849148-1482-4926-9f28-a537630b9ba2
# 302         358           358  b7e4b060-7b74-408f-b7d7-67a5e1dbfce3
# 303         359           359  5870e611-6218-48e1-a9a0-ba86fe5598f7
# 304         361           361  f73a01fe-444d-4b94-8d0e-4ec2cb97495b
# 305         362           362  56e65b5b-e1b4-4f67-b596-e75bf103783b
# ...

# %%
df.iloc[405:431,:]
# Out:
#      Unnamed: 0  Unnamed: 0.1                               User ID  \
# 405         475           475  23cc47ff-e5cd-4915-828d-258aefce5a14
# 406         476           476  5d04455b-a95e-40d8-bcd4-8c485777c47f
# 407         477           477  d56c9d87-7d56-4a5e-a0e8-bbc4ddc3242c
# 408         478           478  2dd186bb-7a28-4e80-99c7-f1936afc7b49
# 409         479           479  317c70d5-fe65-4663-afb1-150108e0e55c
# 410         481           481  953cb190-5704-4926-adc2-057c6f3e3cb4
# 411         483           483  1d8dfb6a-330c-4eb9-a603-364f207c6e57
# 412         485           485  054b5d2a-7ee3-49c8-912a-1cf58389ae60
# 413         487           487  04e52602-e370-4a99-bfda-f0c1655058da
# 414         488           488  fdbaec82-bc98-47b8-8fe6-4aec7524e8e3
# 415         489           489  84bd5adb-286c-429a-926d-4ea120270825
# 416         490           490  b7fb2028-4cfc-440b-a1b1-4101f12f7abe
# 417         491           491  07061727-dc05-4411-ab78-79f95b1869a9
# ...

# %%
df.drop([0,60,180,240,360,480],axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/w7/vb4gczb55g5d0m93s92rl2lc0000gn/T/ipykernel_56112/1658753658.py in <module>
# ----> 1 df.drop([0,60,180,240,360,480],axis=0,inplace=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1                               User ID  \
# 0             1             1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 1             2             2  a8229d24-f219-4930-a382-24049a8f73bb
# 2             4             4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
# 3             5             5  2bd9c167-e06c-47c1-a978-3403d6724606
# 4             8             8  22056f9e-4654-44e9-930d-2fabdeb80f95
# ..          ...           ...                                   ...
# 420         494           494  7246fed1-8725-4dbb-bccd-5451346f122d
# 421         495           495  1f7e22c8-558a-4b6f-a04f-b219593f029e
# 422         497           497  db0066e1-83cc-43f3-990b-983010aa5370
# 423         498           498  d6204684-926d-41db-ae9c-a7bf2e76313a
# 424         499           499  07f4dcd0-2bf3-4f21-9da3-b054b511ae00
#
#                                              Interests  Age
# 0                                           ['tennis']   23
# ...

# %%
df.to_csv("Profile (1).csv")

# %%
df.to_csv("Profile (1).csv", index=False)
